# %% [markdown]
# # Amazon Sales Analysis

# %%
import pandas as pd    #Import Necessary libraries
import os

# %%
#Merge the 12 Months of sales data into a single csv file
#go to csv file path
#open cmd from the particular path
#execute cd CSV files
#execute copy *.csv Amazon_Dataset.csv
#new File created as Amazon_Dataset.csv

# %%
#Read updated dataframes
all_data=pd.read_csv("Amazon_Dataset.csv")
print(all_data)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186857   259354                      iPhone                1        700
# 186858   259355                      iPhone                1        700
# 186859   259356      34in Ultrawide Monitor                1     379.99
# 186860   259357        USB-C Charging Cable                1      11.95
# 186861                                 NaN              NaN        NaN
#
#             Order Date                         Purchase Address
# ...

# %%
print(all_data.head())
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_data.head(5)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
#Check whether there is empty values or nan value
nan_df=all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
#Drop rows of NAN
all_data=all_data.dropna()
print(all_data)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186856   259353      AAA Batteries (4-pack)                3       2.99
# 186857   259354                      iPhone                1        700
# 186858   259355                      iPhone                1        700
# 186859   259356      34in Ultrawide Monitor                1     379.99
# 186860   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
#Find 'Or' and delete it
temp_df=all_data[all_data['Order Date'].str[0:2] =='Or'] #Or cannot be converted to int type find it and delete it
temp_df.head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address
# 519   Purchase Address
# 1149  Purchase Address
# 1155  Purchase Address
# 2878  Purchase Address
# 2893  Purchase Address

# %%
#Find 'Or' and delete it
all_data=all_data[all_data['Order Date'].str[0:2] !='Or']
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
#Convert column to the correct type as cannot multiply sequence by non-int type
all_data['Quantity Ordered']=pd.to_numeric(all_data["Quantity Ordered"]) #make int value
all_data['Price Each']=pd.to_numeric(all_data['Price Each']) #make float

# %% [markdown]
# #Augmented data with additional columns

# %% [markdown]
# # Add Month Column

# %%
all_data['Month']=all_data['Order Date'].str[0:2]
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
all_data['Month']=all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
#ADD a city column
def get_city(address):
    return address.split(',')[1] #having duplicates of cities to overcome this we also want to get the state name to overcome the overlap
def get_state(address):
    return address.split(',')[2].split(' ')[1] #get state to overcome duplicated of the two cities
all_data['City']=all_data['Purchase Address'].apply(lambda x: get_city(x) + '' + get_state(x))


all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month            City
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4        DallasTX
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4        BostonMA
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   Los AngelesCA
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   Los AngelesCA
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   Los AngelesCA

# %%
all_data['Sales']=all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#              City   Sales
# 0        DallasTX   23.90
# 2        BostonMA   99.99
# 3   Los AngelesCA  600.00
# 4   Los AngelesCA   11.99
# 5   Los AngelesCA   11.99

# %% [markdown]
# # Question 1: What was the best month for sales? How much was earned that month?

# %%
results=all_data.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
months= range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD($)')
plt.xlabel('Month number')
plt.show()

# %% [markdown]
# # Question 2: What City had the highest number of sales?

# %%
all_data.groupby('City').sum()
# Out:
#                                                            Order ID  \
# City
#  AtlantaGA        1765641765711765821765891766231766271766341766...
#  AustinTX         1765911766091766741766771766861767011767051767...
#  BostonMA         1765591765661765781765811765851765851766001766...
#  DallasTX         1765581765691765701765771765961766021766101766...
#  Los AngelesCA    1765601765601765611765671765741765741765761765...
#  New York CityNY  1765721765751765791765901765991766131766371766...
#  PortlandME       1767731768791769091770721772301772331772991773...
#  PortlandOR       1765831765931766171766421766461766481766621767...
#  San FranciscoCA  1765621765651765731765841765861765861765941765...
#  SeattleWA        1765631765681765881766121766241766541766631766...
#
#                                                             Product  \
# City
#  AtlantaGA        USB-C Charging CableLightning Charging CableBo...
# ...

# %%
import matplotlib.pyplot as plt
cities= all_data['City'].unique() # #as Above CA has best sale but here Austin is showing best sale to handle this  
plt.bar(cities,results['Sales'])
plt.xticks(cities, rotation='vertical', size=8)
plt.ylabel('Sales in USD($)')
plt.xlabel('City Name')
plt.show()

# %%
#Handle here
import matplotlib.pyplot as plt
cities= [city for city, df in all_data.groupby('City')] 

plt.bar(cities,results['Sales'])
plt.xticks(cities, rotation='vertical', size=8)
plt.ylabel('Sales in USD($)')
plt.xlabel('City Name')
plt.show()

# %% [markdown]
# # Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#              City   Sales
# 0        DallasTX   23.90
# 2        BostonMA   99.99
# 3   Los AngelesCA  600.00
# 4   Los AngelesCA   11.99
# 5   Los AngelesCA   11.99

# %%
all_data['Order Date']=pd.to_datetime(all_data['Order Date'])
# Out:
# C:\Users\Pranjal Kumar Rai\AppData\Local\Temp\ipykernel_11312\2539822065.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   all_data['Order Date']=pd.to_datetime(all_data['Order Date'])

# %%
# Add hour column
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute
all_data['Count'] = 1
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#              City   Sales  Hour  Minute  Count
# 0        DallasTX   23.90     8      46      1
# 2        BostonMA   99.99    22      30      1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Replace this with your actual data loading process
# For example:
# all_data = pd.read_csv('your_data.csv')

# Placeholder data (replace with your actual data)
all_data = pd.DataFrame({
    'Hour': [1, 2, 3, 4, 5],  # Example hour data
    'Count': [10, 15, 12, 18, 20]  # Example count data
})

# Plot the data
hours = [hour for hour, df in all_data.groupby('Hour')]
plt.plot(hours, all_data.groupby(['Hour']).count())
plt.gca().invert_yaxis()  # This line reverses the y-axis
plt.xlabel('Hour')
plt.ylabel('Count')
plt.title('Data Count by Hour')
plt.show()

# %%
plt.figure()
plt.plot(y=range(5),width=data)
plt.plot().invert_xaxis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure()
#       2 plt.plot(y=range(5),width=data)
#       3 plt.plot().invert_xaxis()
#
# NameError: name 'plt' is not defined

# %%
all_data.groupby(['Hour']).count()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hours=[hour for hour, df in all_data.groupby('Hour')]
plt.plot(hours, all_data.groupby(['Hour']).count())
plt.xticks(hours)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

# Aggregate data by hour
hourly_orders = all_data.groupby('Hour').count()

# Extract hours and corresponding order counts
hours = hourly_orders.index
order_counts = hourly_orders['Order ID']

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(order_counts, labels=hours, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Orders Across Hours')
plt.show()

# %% [markdown]
# # Question 4: What products are most often sold together?

# %%
df= all_data[all_data['Order ID'].duplicated(keep=False)] #whose OrderID is same
df.head(20)
#Group them together with new Column having same OrderID
df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
df.head()
# Out:
# C:\Users\Pranjal Kumar Rai\AppData\Local\Temp\ipykernel_11312\1894967240.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address  Month  \
# ...

# %%
#Drop the duplicated Orders of same pair
df=df[['Order ID', 'Grouped']].drop_duplicates()
df.head()
# Out:
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
import matplotlib.pyplot as plt

# Count the frequency of each unique pair in 'Grouped' column
pair_counts = df['Grouped'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(10, 8))
plt.pie(pair_counts, labels=pair_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Unique Order Pairs')
plt.show()

# %%
#Count the pairs
#new Libraries
from itertools import combinations
from collections import Counter

count = Counter()
for row in df['Grouped']:
    row_list=row.split(',')
    count.update(Counter(combinations(row_list, 2)))
print(count)
# Out:
# Counter({('iPhone', 'Lightning Charging Cable'): 1005, ('Google Phone', 'USB-C Charging Cable'): 987, ('iPhone', 'Wired Headphones'): 447, ('Google Phone', 'Wired Headphones'): 414, ('Vareebadd Phone', 'USB-C Charging Cable'): 361, ('iPhone', 'Apple Airpods Headphones'): 360, ('Google Phone', 'Bose SoundSport Headphones'): 220, ('USB-C Charging Cable', 'Wired Headphones'): 160, ('Vareebadd Phone', 'Wired Headphones'): 143, ('Lightning Charging Cable', 'Wired Headphones'): 92, ('Lightning Charging Cable', 'Apple Airpods Headphones'): 81, ('Vareebadd Phone', 'Bose SoundSport Headphones'): 80, ('USB-C Charging Cable', 'Bose SoundSport Headphones'): 77, ('Apple Airpods Headphones', 'Wired Headphones'): 69, ('Lightning Charging Cable', 'USB-C Charging Cable'): 58, ('Lightning Charging Cable', 'AA Batteries (4-pack)'): 55, ('Lightning Charging Cable', 'Lightning Charging Cable'): 54, ('Bose SoundSport Headphones', 'Wired Headphones'): 53, ('AA Batteries (4-pack)', 'Lightning Charging Cable
# ...

# %%
#format this combination
count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
#for key and value
for key, value in count.most_common(10):   #Combinations or common pair user buy
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92
